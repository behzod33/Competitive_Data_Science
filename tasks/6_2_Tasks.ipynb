# %% [markdown]
# # Задача на 3-ом шаге урока

# %% [markdown]
# **Застекай их**

# %% [markdown]
# Объявите модель StackingClassifier(), которая в качестве базовых моделей будет принимать список estimators, а в качестве метамодели использует LogisticRegression().

# %%
# !pip install catboost xgboost lightgbm
# Out:
# Collecting catboost
#   Using cached catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.12/dist-packages (3.2.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.12/dist-packages (4.6.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from catboost) (0.21)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.0.2)
# Requirement already satisfied: pandas<4.0,>=0.24 in /usr/local/lib/python3.12/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from catboost) (1.16.3)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: nvidia-nccl-cu12 in /usr/local/lib/python3.12/dist-packages (from xgboost) (2.29.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<4.0,>=0.24->catboost) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (26.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->catboost) (3.3.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->catboost) (9.1.4)
# Downloading catboost-1.2.10-cp312-cp312-manylinux2014_x86_64.whl (97.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.1/97.1 MB 7.3 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.10

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import StackingClassifier, RandomForestClassifier
from catboost import CatBoostClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

estimators = [
    ('logreg', LogisticRegression()),
    ('rf', RandomForestClassifier()),
    ('catboost', CatBoostClassifier()),
    ('xgboost', XGBClassifier()),
    ('lightgbm', LGBMClassifier())
]

meta_model = StackingClassifier(
    estimators=estimators,
    final_estimator=LogisticRegression()
)

# %% [markdown]
# # Задача на 5-ом шаге урока

# %% [markdown]
# **Разгоняем метамодель**

# %% [markdown]
# Ссылка на данные для тестирования

# %%
import pandas as pd
import itertools

path = 'https://stepik.org/media/attachments/lesson/825511/meta_feautres_data.csv'
df = pd.read_csv(path)
df.head()
# Out:
#    index     target     model
# 0      0  65.927922  catboost
# 1      1  44.248116  catboost
# 2      2  43.807966  catboost
# 3      3  45.661121  catboost
# 4      4  43.653036  catboost

# %%
rename_columns = {f'{i}': f'target_{i}' for i in df['model'].value_counts().index}

result_df = df.pivot(
    index='index',
    columns='model',
    values='target'
)


models = result_df.columns.tolist()

for i, j in itertools.combinations(models, 2):
  result_df[f'{i}_div_{j}'] = result_df[i] / result_df[j]
  result_df[f'{i}_dif_{j}'] = result_df[i] - result_df[j]



result_df.rename(columns=rename_columns).reset_index()
# Out:
# model  index  target_catboost  target_lgbm  target_xgb  catboost_div_lgbm  \
# 0          0        65.927922    49.622930   55.741352           1.328578
# 1          1        44.248116    43.244205   42.661655           1.023215
# 2          2        43.807966    45.389293   42.217470           0.965161
# 3          3        45.661121    44.769051   40.969734           1.019926
# 4          4        43.653036    40.462658   38.243040           1.078847
# ..       ...              ...          ...         ...                ...
# 580      580        43.372847    44.205443   39.795555           0.981165
# 581      581        44.168977    42.959736   42.351254           1.028148
# 582      582        44.393186    43.844842   44.074200           1.012506
# 583      583        43.649487    46.200331   40.630420           0.944787
# 584      584        44.128439    45.071626   43.850530           0.979074
#
# model  catboost_dif_lgbm  catboost_div_xgb  catboost_dif_xgb  lgbm_div_xgb  \
# 0              16.304993          1.182747         10.186570      0.890235
# 1               1.003911          1.037187          1.586461      1.013655
# 2              -1.581327          1.037674          1.590496      1.075131
# 3               0.892070          1.114509          4.691387      1.092735
# 4               3.190378          1.141464          5.409996      1.058040
# ..                   ...               ...               ...           ...
# 580            -0.832596          1.089892          3.577292      1.110814
# 581             1.209241          1.042920          1.817723      1.014368
# 582             0.548344          1.007237          0.318986      0.994796
# 583            -2.550844          1.074306          3.019067      1.137087
# 584            -0.943187          1.006338          0.277909      1.027847
#
# model  lgbm_dif_xgb
# 0         -6.118422
# 1          0.582550
# 2          3.171823
# 3          3.799317
# 4          2.219618
# ..              ...
# 580        4.409888
# 581        0.608482
# 582       -0.229358
# 583        5.569911
# 584        1.221096
#
# [585 rows x 10 columns]

# %%
result_df
# Out:
# model   catboost       lgbm        xgb  catboost_div_lgbm  catboost_dif_lgbm  \
# index
# 0      65.927922  49.622930  55.741352           1.328578          16.304993
# 1      44.248116  43.244205  42.661655           1.023215           1.003911
# 2      43.807966  45.389293  42.217470           0.965161          -1.581327
# 3      45.661121  44.769051  40.969734           1.019926           0.892070
# 4      43.653036  40.462658  38.243040           1.078847           3.190378
# ...          ...        ...        ...                ...                ...
# 580    43.372847  44.205443  39.795555           0.981165          -0.832596
# 581    44.168977  42.959736  42.351254           1.028148           1.209241
# 582    44.393186  43.844842  44.074200           1.012506           0.548344
# 583    43.649487  46.200331  40.630420           0.944787          -2.550844
# 584    44.128439  45.071626  43.850530           0.979074          -0.943187
#
# model  catboost_div_xgb  catboost_dif_xgb  lgbm_div_xgb  lgbm_dif_xgb
# index
# 0              1.182747         10.186570      0.890235     -6.118422
# 1              1.037187          1.586461      1.013655      0.582550
# 2              1.037674          1.590496      1.075131      3.171823
# 3              1.114509          4.691387      1.092735      3.799317
# 4              1.141464          5.409996      1.058040      2.219618
# ...                 ...               ...           ...           ...
# 580            1.089892          3.577292      1.110814      4.409888
# 581            1.042920          1.817723      1.014368      0.608482
# 582            1.007237          0.318986      0.994796     -0.229358
# 583            1.074306          3.019067      1.137087      5.569911
# 584            1.006338          0.277909      1.027847      1.221096
#
# [585 rows x 9 columns]

# %% [markdown]
# # Задача на 6-ом и 7-ом шаге урока

# %% [markdown]
# **Пишем свой стекер и обучаем его**

# %% [markdown]
# На 6-ом шаге урока пишем класс Blender.
# На 7-ом шаге урока воспользуйся классом Blender, который написал на предыдущем задании, и обучи свой ансамбль.

# %% [markdown]
# Для тестирования на данных можно взять датасет

# %%
from sklearn import datasets
from sklearn.model_selection import train_test_split

X, y = datasets.load_diabetes(return_X_y=True)
X_train, X_holdout, y_train, y_holdout = train_test_split(X, y, random_state=42, shuffle=True)

# %% [markdown]
# Решение шаг 6

# %%
class Blender:
    def __init__(self, base_models, meta_model):
        """
        base_models - список базовых моделей, которые нужно обучать на изначальных данных
        meta_model - мета модель, которая обучается на предсказаниях базовых моделей
        Считайте, что модель, которая передается имеет поля .fit(X_train, y_train) и .predict(X_test)
        .predict(X_test) возвращает предсказания размерности (n_samples,)
        """
        self.base_models = base_models
        self.meta_model = meta_model

    def fit(self, X_train, y_train, X_hold, y_hold):
        #TODO
        pass

    def predict(self, X_test):
        #TODO
        #preds =
        #TODO
        return preds

# %% [markdown]
# Решение шаг 7

# %%
from sklearn.linear_model import LinearRegression, LassoCV
from sklearn.svm import SVR
base_models = [LinearRegression(), LassoCV(), SVR()]
X_train, X_holdout, y_train, y_holdout = train_test_split(X, y, random_state=42, shuffle=True)
# Теперь обучи свой ансамбль и положи предсказания на X_holdout в переменную preds
# your code here
preds = # your code here

# %% [markdown]
# # Задача на 10-ом шаге урока

# %% [markdown]
# **Пишем CV**

# %% [markdown]
# Для тестирования функции можно использовать следующий код:

# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.svm import SVR

X, y = datasets.load_diabetes(return_X_y=True)
X = pd.DataFrame(X)

base_models = [LinearRegression(), Lasso(), SVR()]
for model in base_models:
  GetPreds(model, X, y)

# %% [markdown]
# Решение

# %%
def GetPreds(model, X, y, n_fold=5):
    """
    model - имеет методы .fit(X, y) и .predict(X)
    X - pd.DataFrame
    y - np.array
    """
    folds = KFold(n_splits=n_fold)
    preds = np.empty((0,1), float)

    for train_indices, val_indices in folds.split(X, y):
        #your code here

    return preds.reshape(-1, 1)

# %% [markdown]
# # Задача на 11-ом шаге урока

# %% [markdown]
# **Добавляем X_test**

# %% [markdown]
# Модифицируйте функцию из предыдущей задачи, чтобы она, помимо предсказаний на весь X, еще возвращала предсказания на X_test. Для того чтобы получить предсказания на X_test, обучите данную модель сразу на всей выборке.

# %% [markdown]
# Для тестирования функции можно использовать следующий код:

# %%
from sklearn import datasets
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.svm import SVR

X, y = datasets.load_diabetes(return_X_y=True)
X = pd.DataFrame(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42, shuffle=True)

base_models = [LinearRegression(), Lasso(), SVR()]
for model in base_models:
  GetPreds(model, X, y, X_test)

# %% [markdown]
# Решение

# %%
def GetPreds(model, X, y, X_test, n_fold=5):
    """
    model - имеет методы .fit(X, y) и .predict(X)
    X - pd.DataFrame
    y - np.array
    X_test - pd.DataFrame, для которого нужно сделать предсказания
    """
    folds = KFold(n_splits=n_fold)
    preds = np.empty((0,1),float)

    for train_indices, val_indices in folds.split(X, y):
        # your code here

    test_preds = # your code here
    return preds.reshape(len(X), 1), test_preds.reshape(len(X_test), 1)
